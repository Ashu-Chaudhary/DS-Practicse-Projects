# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.describe().T
# Out:
#                                count       mean        std      min  \
# Happiness Rank                 158.0  79.493671  45.754363  1.00000
# Happiness Score                158.0   5.375734   1.145010  2.83900
# Standard Error                 158.0   0.047885   0.017146  0.01848
# Economy (GDP per Capita)       158.0   0.846137   0.403121  0.00000
# Family                         158.0   0.991046   0.272369  0.00000
# Health (Life Expectancy)       158.0   0.630259   0.247078  0.00000
# Freedom                        158.0   0.428615   0.150693  0.00000
# Trust (Government Corruption)  158.0   0.143422   0.120034  0.00000
# Generosity                     158.0   0.237296   0.126685  0.00000
# Dystopia Residual              158.0   2.098977   0.553550  0.32858
#
#                                      25%        50%         75%        max
# Happiness Rank                 40.250000  79.500000  118.750000  158.00000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr=df.corr()

# %%
corr
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.pairplot(df,size=10)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
 df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

# %%
le=LabelEncoder()
list1=['Region','Country']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0         41       9               1            7.587         0.03411
# 1        112       9               2            7.561         0.04884
# 2         89       9               3            7.527         0.03328
# 3          8       9               4            7.522         0.03880
# 4         75       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153       22       8             154            3.465         0.03464
# 154       35       8             155            3.340         0.03656
# 155       42       4             156            3.006         0.05015
# 156       72       8             157            2.905         0.08658
# 157       48       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df1=df.loc[(z_score<3).all(axis=1)]
print(df1.shape)
# Out:
# (158, 12)
# (149, 12)

# %%
sns.heatmap((df.corr="pearson"))
# Out:
#   File "<ipython-input-38-aef28658e504>", line 1
#     sns.heatmap((df.corr="pearson"))
#                         ^
# SyntaxError: invalid syntax

# %%
df.plot.box()

# %%
plt.scatter(df['Family'],df['Happiness Score'])
plt.xlabel("family")
plt.ylabel("Happiness Score")
plt.show()

# %%
plt.scatter(df['Family'],df['Happiness Score'])

# %%
df1.skew()
# Out:
# Country                         -0.032869
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#seprating target and input variable
df1_x=df1.drop(columns=['Happiness Score'])
y=df1[['Happiness Score']]

# %%
#scaling the input variables for linear regression algo
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df1_x)
x=pd.DataFrame(x,columns=df1_x.columns)

# %%
#check the skewness again
x.skew()
# Out:
# Country                         -0.032869
# Region                          -0.096985
# Happiness Rank                   0.003268
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45,test_size=0.25)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.25)
    reg=linear_model.LinearRegression()
    reg.fit(x_train,y_train)
    y_pred=reg.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print("maxr2 score",final_r_state,"is",max_r_score)
# Out:
# maxr2 score 92 is 0.9999999472838222

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=10,scoring="r2").mean()
# Out:
# 0.9999898849535278

# %%
cross_val_score(linear_model.LinearRegression(),x,y,cv=10,scoring="r2")
# Out:
# array([0.99999456, 0.99999743, 0.99999847, 0.99997529, 0.99999622,
#        0.99998319, 0.99997635, 0.99998196, 0.99999645, 0.99999893])

# %%
#max r2 score we get random state 92
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=92,test_size=0.25)

reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("r2 score is:",r2_score(y_test,y_pred))
print("RMSE is",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is: 0.9999999472838222
# RMSE is 0.0002683955213211587

# %%
#lets save this model
from sklearn.externals import joblib
joblib.dump(reg,'WHR.pkl')
# Out:
# ['WHR.pkl']
